# %% [markdown]
# # Fluent Python p5, card deck
#
# 6/10/2020, env fluentpy

# %%
# !python --version
# Out:
# Python 3.5.6 :: Anaconda, Inc.

# %%
pwd
# Out:
# '/home/jyoon/work/fluentpy/exercises'

# %%
import collections
