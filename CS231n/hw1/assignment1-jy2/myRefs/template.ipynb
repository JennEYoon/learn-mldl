# %% [markdown]
# # template file
# For use with conda env: cs231, Python version = 3.7.3
# For use with Jupyter Lab and VS Code IDE in terminal.
# Imports common libraries

# %%
# !python --version
# Out:
# Python 3.7.3

# %% [markdown]
# # Description.
# Put information on project purpose here.

# %%
# Auto reload external python files
# %load_ext autoreload
# %autoreload 2

# %%
# Import datatime, to automatically timestamp work.
# To do later.

# %%
# Import data exploration and plotting libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Description.
# Put information on data source and how it is used here.

# %% [markdown]
# # Data Processing Step

# %%
# Import sklearn.preprocessing
# from sklearn.preprocessing import ...

# %%
# !cmd
# Out:
# Can't find a default Python.
