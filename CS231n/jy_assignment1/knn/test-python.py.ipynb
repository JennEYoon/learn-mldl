# %% [markdown]
# ## codeshare test-python.py
# https://codeshare.io/50ZvXm

# %%
import numpy as np
import pandas as pd
lista = [1, 2, 3, 4]
listb = ['A', 'B', 'C', 'D']
listc = ['Dan', 'Elsa', 'Peter', 'Jennifer']
df = pd.DataFrame(zip(lista, listb, listc))  
# When you copy, make sure you get the two )) at end.
print(df)
# Out:
#    0  1         2
# 0  1  A       Dan
# 1  2  B      Elsa
# 2  3  C     Peter
# 3  4  D  Jennifer
